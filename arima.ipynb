# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
from matplotlib import pyplot as plt
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt
# Out:
# <ipython-input-31-df9b4975e5ee>:5: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
df = pd.read_csv("train_data.csv", index_col=0, parse_dates=True, squeeze=True)
df.tail()
# Out:
# Date
# 2018-12-03    124.30
# 2018-12-10    122.37
# 2018-12-17    121.02
# 2018-12-24    120.61
# 2018-12-31    120.18
# Name: Petrol (USD), dtype: float64

# %%
# Out:
# Date
# 2003-06-09    False
# 2003-06-16    False
# 2003-06-23    False
# 2003-06-30    False
# 2003-07-07    False
#               ...
# 2018-12-03    False
# 2018-12-10    False
# 2018-12-17    False
# 2018-12-24    False
# 2018-12-31    False
# Name: Petrol (USD), Length: 813, dtype: bool

# %%
df2 = df.dropna()
df3=df2[df2<160]
df3.head()
df_test=pd.read_csv("test_data.csv", parse_dates=True, squeeze=True, index_col=0)
df_test.head()
# Out:
# Date
# 2019-01-01   NaN
# 2019-01-02   NaN
# 2019-01-03   NaN
# 2019-01-04   NaN
# 2019-01-05   NaN
# Name: Prediction, dtype: float64

# %%
model1 = ARIMA(df3.values, order=(5,1,0))
model_fit1 = model1.fit()
output1= model_fit1.forecast(steps=12)
output1
# Out:
# array([119.806706  , 119.52143357, 119.30634703, 119.14818612,
#        119.02925502, 118.93899227, 118.87071737, 118.81917644,
#        118.78030465, 118.75097738, 118.72884041, 118.71213032])

# %%
# Out:
# predicted=137.417744, expected=136.950000
# predicted=136.679700, expected=133.400000
# predicted=131.264206, expected=131.620000
# predicted=130.507738, expected=131.670000
# predicted=131.447209, expected=131.530000
# predicted=131.297980, expected=131.420000
# predicted=131.335352, expected=129.920000
# predicted=128.981520, expected=129.710000
# predicted=129.590734, expected=129.890000
# predicted=129.893075, expected=130.030000
# predicted=130.084074, expected=130.250000
# predicted=130.365474, expected=130.760000
# predicted=131.067902, expected=130.960000
# predicted=131.091870, expected=130.050000
# predicted=129.546486, expected=130.030000
# predicted=130.048658, expected=130.260000
# predicted=130.341118, expected=130.360000
# predicted=130.411085, expected=129.370000
# predicted=128.788916, expected=129.020000
# predicted=128.835334, expected=128.850000
# predicted=128.689826, expected=128.810000
# predicted=128.752157, expected=129.160000
# ...

# %%
# Out:
# [74.59003294 74.39226184 74.38674278 74.29887476 74.23256095 74.16166475
#  75.61692796 75.08595838 75.17705029 75.65329536 76.04858081 76.20948016]
